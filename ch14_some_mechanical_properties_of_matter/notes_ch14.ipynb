# %% [markdown]
# # ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-14 SOME MECHANICAL PROPERTIES OF MATTER________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.1 MOLECULAR STRUCTURE OF A MATERIAL__

# %% [markdown]
# - Matter is made up of molecules and atoms
#
# - An atom is made of nucleus and electrons
#
# - The nucleus contains positively charged protons and nuetrons (nucleons).
#
# - Electromagnetic forces operate between a pair of electrons and between an electron and the nucleus

# %% [markdown]
# __Interatomic and Intermolecular Forces__

# %% [markdown]
# - A polyatomic molecule is formed when the atoms are arranged in such a fashion that the total potential energy of the system is minimum
#
# - The force between atoms is called interatomic force and the forces between molecules is called intermolecular force

# %% [markdown]
# __Bonds__

# %% [markdown]
# - The atoms form molecules primarily due to the electrostatic interaction between the electrons and the nuclei.
#
# - These interactions are described in terms of different kinds of bonds

# %% [markdown]
# __Ionic Bonds__

# %% [markdown]
# - In an ionic bond, two atoms come close to each other and an electron is completely transferred from one atom to the other
#
# - This leaves the first atom positively charged and the other one negatively charged.
#
# - Eg: The positively charged sodium ion and negatively charged chlorine ion attract each other to form an ionic bond resulting in sodium chloride molecule

# %% [markdown]
# __Covalent Bond__

# %% [markdown]
# - Electrons from neighbouring atoms are made available for sharing between the atoms and is called a covalent bond
#
# - When two hydrogen (H) atoms come close to each other, both the electrons are available to both the nuclei
#
# - Another example is hydrogen chloride (HCl) molecule

# %% [markdown]
# __Three States of Matter__

# %% [markdown]
# _Solids_

# %% [markdown]
# - Definite shape and volume – they don’t change shape unless force is applied.
# - Particles are tightly packed – arranged in fixed positions.
# - Strong intermolecular forces – particles only vibrate in place.
# - Incompressible – cannot be squashed easily.
# - High density compared to liquids and gases.

# %% [markdown]
# _Liquids_
#
# - Definite volume but no fixed shape – they take the shape of their container.
# - Particles are close but can slide past each other – allows flow.
# - Moderate intermolecular forces – weaker than solids, stronger than gases.
# - Almost incompressible – but slightly more compressible than solids.
# - Medium density – usually less than solids but more than gases.

# %% [markdown]
# _Gases_

# %% [markdown]
# - No definite shape or volume – they expand to fill the container.
# - Particles are far apart – move freely and randomly.
# - Weak intermolecular forces – negligible compared to solids and liquids.
# - Highly compressible – can be squashed easily.
# - Low density compared to solids and liquids.

# %% [markdown]
# __Solid State__

# %% [markdown]
# - The equilibrium positions have a very regular three dimensional arrangement which is called _crystal_
#
# - The positions occupied by the molecules or the ions are called lattice points

# %% [markdown]
# __Molecular Solid__

# %% [markdown]
# - In a molecular solid, the molecules are formed due to covalent bonds between the atoms
#
# - It depends on whether the molecules are _polar_ or _nonpolar_
#
# - If the centre of negative charge in a molecule coincides with the centre of the poisitive charge, the molecule is _nonpolar_. Eg: Molecules of H, O, Cl, etc
#
# - Otherwise, the molecule is polar. Eg: H₂O
#
# - The bond between polar molecules is called a __dipole-dipole bond__
#
# - The bond between nonpolar molecules is called a __van der Waals bond__
#
# - Molecular solids are usually soft and have low melting point. They are poor conductors of electricity

# %% [markdown]
# __Ionic Solid__

# %% [markdown]
# - In an ionic solid, the lattice points are occupied by positive and negative ions
#
# - The electrostatic attractions between these ions bind the solid
#
# - These attraction forces are quite strong so that the material is usually hard and has fairly high melting point
#
# - They are poor conductors of electricity

# %% [markdown]
# __Covalent solid__

# %% [markdown]
# - In a covalent solid the atoms are arranged in the crystalline form
#
# - The neighbouring atoms are bound by shared electrons
#
# - Eg: Diamond, silicon,etc
#
# - They are quite hard, have high melting point and are poor conductors of electricity

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.2 ELASTICITY__

# %% [markdown]
# - Property of a body by virtue of which it regains its shape and size after removal of deforming force
#
# - If a body completely gains its natural shape after removal of deforming forces, it is called a perfectly elastic body
#
# - If a body remians in the deformed state and does not even partially regain its original shape after removal of the deforming forces, it is called a perfectly inelastic or plastic body
#
# - Steel > Rubber > Plastic

# %% [markdown]
# __Microscopic Reason for Elasticity__

# %% [markdown]
# - When deforming force is applied on a body, some internal ressistance is developed in body due to intermolecular force, this is called as restoring force

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.3 STRESS__

# %% [markdown]
# - It is defined as the restoring force acting per unit area.
#
# - Stress (σ) = F(restoring)/Area
#
# - SI = N/m²
#
# - Dimension = [ML-¹T-²]

# %% [markdown]
# - Types of stress
#
#     - Longitudinal Stress
#
#     - Shear Stress
#
#     - Volume Stress

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.4 STRAIN__

# %% [markdown]
# - Strain = Change in the dimension of body/Original dimension of body
#
# - Strain is dimensionless
#
# - Strain is unitless

# %% [markdown]
# - Types of strain
#
#     - Longitudinal Strain
#
#     - Shear Strain
#
#     - Volume Strain

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.5 HOOKE'S LAW AND THE MODULII OF ELEASTICITY__

# %% [markdown]
# - If the deformation is small, the stress in a body is proportional to the corresponding strain

# %% [markdown]
# - stress ∝ strain [upto eleastic limit]
#
# - stress = E strain
#
# - E = stress/strain = Modulus of elasticity

# %% [markdown]
# Types of modulus
#
# - Young's Modulus
#
# - Shear Modulus
#
# - Bulk Modulus
#
# - Stress Strain Curve

# %% [markdown]
# __Table 14.1 : _Elastic Constants___

# %% [markdown]
# __Material ----- Young Modulus ------ Shear Modulus ----- Bulk Modulus ----- Poisson Ratio(σ)__
#
# - Aluminium ----- 0.70 ---------------- 0.30 -------------- 0.70 ------------- 0.16
#
# - Brass --------- 0.91 ---------------- 0.36 ------------- 0.61 -------------- 0.26
#
# - Copper -------- 1.1 --------------- 0.42 --------------- 1.4 -------------- 0.32
#
# - Iron ---------- 1.9 --------------- 0.70 -------------- 1.0 --------------- 0.27
#
# - Steel --------- 2.0 --------------- 0.84 -------------- 1.6 --------------- 0.19
#
# - Tungsten ------- 3.6 ------------- 1.5 ---------------- 2.0 --------------- 0.20

# %% [markdown]
# __Table 14.2 : _Compressibilites of liquids___

# %% [markdown]
# - __--- Liquid ----------------------- Compressiblity K 10-¹¹ m² N-¹__
#
# - Carbon disulphide ----------------------- 64
#
# - Ethyl alcohol ----------------------------- 110
#
# - Glycerine --------------------------------- 21
#
# - Mercury ---------------------------------- 3.7
#
# - Water ------------------------------------ 49

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.6 RELATION BETWEEN LONGITUDINAL STRESS AND STRAIN__

# %% [markdown]
# __Metal Wire__

# %% [markdown]
# - When the strain is small (<0.01), the stress is proportional to the strain
#
# - This is the region where Hooke's Law is valid and where Young's module is defined
#
# - The point on the curve upto which stress and strain are proportional represents the _proportional limit_
#
# - If deformation is increased further, the wire breaks at a point called _fracture point_
#
# - The stress corresponding to this point is called _breaking stress_
#
# - If large deformation takes place between the elastic limit and the fracture point, the material is called _ductile_. If it breaks soon after the elastic limit is crossed, it is called _brittle_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.7 ELASTIC POTENTIAL ENERGY OF A STRAINED BODY__

# %% [markdown]
# - When a body is in its natural shape, its potential energy corresponding to the moleculer forces is minimum. When deformed, internal forces appear, and work has to be done against these forces. Thus potential energy of the body is increased. This is called _elastic potential energy_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.8 DETERMINATION OF YOUNG MODULUS IN LABORATORY__

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.9 SURFACE TENSION__

# %% [markdown]
# __Table 14.3 : _Surface Tension___

# %% [markdown]
# - __--- Liquid ---------------------- Surface Tension N m-¹__
#
# - Carbon tetra chloride --------------------- 0.027
#
# - Ethyl alcohol ----------------------------- 0.022
#
# - Glycerine --------------------------------- 0.063
#
# - Mercury ---------------------------------- 0.465
#
# - Water ------------------------------------ 0.075
#
# - Soap Solution --------------------------- 0.030

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.10 SURFACE ENERGY__

# %% [markdown]
# - In this the surface remains in microscopic turbulence
#
# - The extra energy that a surface has is called _surface energy_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.11 EXCESS PRESSURE INSIDE A DROP__

# %% [markdown]
# - The pressure inside a surface is greater than the pressure outside the surface by an amount 2S/R

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.12 EXCESS PRESSURE IN A SOAP BUBBLE__

# %% [markdown]
# - The pressure inside a surface is greater than the pressure outside the surface by an amount 4S/R

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.13 CONTACT ANGLE__

# %% [markdown]
# - The angle between the tangeant planes at the solid surface and the liquid surface at the contact is called contact angle

# %% [markdown]
# __Table 14.4 : _Contact Angle___

# %% [markdown]
# - __--- Substance ---------------------- Contact Angle__
#
# - Water with glass --------------------- 0°
#
# - Water with paraffin ------------------ 107°
#
# - Methylene iodide with glass ---------- 29°
#
# - Mercury with glass-------------------- 140°

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.14 RISE OF LIQUID IN A CAPILLARY TUBE__

# %% [markdown]
# - When one end of a tube of small radius (known as a capillary tube) is dipped into a liquid, the liquid rises or is depressed in the tube
#
# - If contact angle is less than 90°, the liquid rises
#
# - If it is greater than 90°, it is depressed

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.15 VISCOSITY__

# %% [markdown]
# - When a layer of fluid slips or tends to slip on another layer in contact, the two layers exert tangential forces on each other
#
# - The property of a fluid to oppose relative motion between its layers is called _viscosity_
#
# - The forces between the layers opposing relative motion between them are known as the _forces of viscosity_

# %% [markdown]
# __Dimensions of the Coefficient of Viscosity__

# %% [markdown]
# [η] = ML-¹T-¹

# %% [markdown]
# __Table 14.5 : _Cooefficient of viscosity___

# %% [markdown]
# __-- Temperature (°C) -- Viscosity of castor oil, poise -- Viscosity of water, centipoise -- Viscosity of air, micropoise__
#
# - ------- 0 ---------------------- 53 --------------------------------- 1.792 ------------------------- 171
#
# - ------- 20 ------------------- 9.86 --------------------------------- 1.005 ------------------------- 181
#
# - ------- 40 ------------------- 2.31 --------------------------------- 0.656 ------------------------- 190
#
# - ------- 60 ------------------- 0.80 --------------------------------- 0.469 ------------------------- 200
#
# - ------- 80 ------------------- 0.30 --------------------------------- 0.357 ------------------------- 209
#
# - ------ 100 ------------------- 0.17 --------------------------------- 0.284 ------------------------- 218

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.16 FLOW THROUGH A NARROW TUBE : POISEUILLE'S EQUATION__

# %% [markdown]
# - Rate of flow is
#
# - V/t = πPr⁴/8ηl
#
# - This is _Poiseullie's equation_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.17 STOKES' LAW__

# %% [markdown]
# - F = 6 π η r v
#
# - This equation is known as _Stokes' law_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __14.18 TERMINAL VISCOSITY__

# %% [markdown]
# - When a solid is dropped in a fluid, the forces acting on it are
#
#     1. weight W acting vertically downward
#
#     2. the viscous force F acting vertically upward
#
#     3. the buoyancy force B acting vertically upward

# %% [markdown]
# - v₀ = 2 r²(ρ - σ)g/9η
