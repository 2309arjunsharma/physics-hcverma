# %% [markdown]
# # __CH18 SHORT ANSWER QUESTIONS__

# %% [markdown]
# __Q1__

# %% [markdown]
# - The formula is not valid when viewed from a distance

# %% [markdown]
# __Q2__

# %% [markdown]
# - In different mediums speed of light is different
#
# - Yes, we have a situation in which light ray goes undeviated through prism
#
# - When the refractive index of surrounding equal to the refractive index of prism

# %% [markdown]
# __Q3__

# %% [markdown]
# - μ(diamond) > μ(glass)
#
# - So more refraction in diamond
#
# - So, therefore, diamond shines more than glass

# %% [markdown]
# __Q4__

# %% [markdown]
# - Since μ of slab fluctuates with time therefore, the light appears twinkling

# %% [markdown]
# __Q5__

# %% [markdown]
# - Yes, a plane mirror can form a real image of virtual object

# %% [markdown]
# __Q6__

# %% [markdown]
# - If piece of paper is placed at the position of a virtual image, the paper will not burn

# %% [markdown]
# - As no light rays are meeting in actual
#
# - If image is real than paper will burn

# %% [markdown]
# __Q7__

# %% [markdown]
# - Yes you can do it

# %% [markdown]
# __Q8__

# %% [markdown]
# - A convex mirror can form a diminished image which a plane mirror can't

# %% [markdown]
# __Q9__

# %% [markdown]
# - It will move slower

# %% [markdown]
# __Q10__

# %% [markdown]
# - We find the friend taller

# %% [markdown]
# __Q11__

# %% [markdown]
# - = μ₂/μ₁

# %% [markdown]
# __Q12__

# %% [markdown]
# - No, it does not

# %% [markdown]
# __Q13__

# %% [markdown]
# - Diverging lens diverges parallel rays

# %% [markdown]
# __Q14__

# %% [markdown]
# - Diverging

# %% [markdown]
# __Q15__

# %% [markdown]
# - Small lens should be placed within the focus of bigger

# %% [markdown]
# __Q16__

# %% [markdown]
# - Spherical mirror's focal length doesn't depend on medium

# %% [markdown]
# __Q17__

# %% [markdown]
# - As the focal length of lens is medium dependent
#
# - We can say that the refractive index of lens will change if dipped in water

# %% [markdown]
# __Q18__

# %% [markdown]
# - Chromatic aberration is a defect of lens
#
# - 'f' of lens depends on μ
#
# - Mirror does not depend on medium
#
# - Mirrors do no form chromatic aberration

# %% [markdown]
# __Q19__

# %% [markdown]
# - Laser light is monochromatic
#
# - Its wavelength is nearby
#
# - μ = a + b/λ²
#
# - μ almost same
#
# - f almost same
#
# - No significant chromatic aberration
