# %% [markdown]
# # __CH-18 GEOMETRICAL OPTICS__

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# - To find path of light we deal with _geometrical optics_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.1 REFLECTION AT SMOOTH SURFACES__

# %% [markdown]
# - When a ray of light approaches a smooth polished surface and the light ray bounces back, it is called the reflection of light

# %% [markdown]
# __Laws of Reflection__

# %% [markdown]
# 1. The angle of incidence is always equal to the angle of reflection
#
# 2. The incident ray, reflected ray and normal to the reflected surface at the point of incidence, all lie in the same plane

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.2 SPHERICAL MIRRORS__

# %% [markdown]
# - Spherical mirrors are made of glass
#
# - One side is silvered
#
# - Reflection takes place on the other side
#
# - If reflection takes place on the convex surface, it is a _convex mirror_
#
# - If reflection takes place on the concave surface, it is a _concave mirror_

# %% [markdown]
# - The centre of the sphere of which the mirror forms a part is called _centre of curvature_

# %% [markdown]
# - The radius of this sphere is called _radius of curvature_

# %% [markdown]
# - The point on the mirror  at the middle of the surface is called _pole_

# %% [markdown]
# - The line joining the pole and the centre of curvature is called _principal axis_

# %% [markdown]
# __Focus__

# %% [markdown]
# - The point where the reflected rays converge is called the focus of the mirror
#
# - The plane through the focus and perpendicular to the principal axis is called the _focal plane_
#
# - The distance of the focus from the pole is called _focal length_

# %% [markdown]
# __Paraxial Rays__

# %% [markdown]
# - A ray close to the principal axis is called a paraxial ray

# %% [markdown]
# __Image Tracing__

# %% [markdown]
# - If the reflected rays intersect, the point of intersection is the _real image_
#
# - If the rays diverge after reflection, a virtual image is formed

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.3 RELATION BETWEEN _u_, _v_ AND _R_ FOR SPHERICAL MIRRORS__

# %% [markdown]
# - 1/v + 1/u = 1/F = 2/R

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.4 EXTENDED OBJECTS AND MAGNIFICATION__

# %% [markdown]
# __Lateral Magnifcation__

# %% [markdown]
# - The ratio (height of the image/height of the objective) is called _lateral_ or _transverse magnification_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.5 REFRACTION AT PLANE SURFACES__

# %% [markdown]
# - When a light ray is incident on a surface separating two transparent media, the ray bends at the time of changing the medium
#
# - The angle of incidence _i_ and the angle of refraction _r_ follow ___Snell's Law___
#
# - sin _i_/sin _r_ = ν₁/ν₂ = μ₂/μ₁

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.6 CRITICAL ANGLE__

# %% [markdown]
# - Critical angle is the angle made in denser medium for which the angle of refraction in rarer medium is 90
#
# - When angle in denser medium is more than critical angle the light ray reflects back in denser medium following the laws of reflection and the interface behaves like a perfectly reflecting mirror

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.7 OPTICAL FIBRE__

# %% [markdown]
# - An _optical fibre_ is a very thin fibre made of glass or plastic having a radius of the order of a micrometre (10-⁶ m)
#
# - A bundle of such thin fibres forms a _light pipe_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.8 PRISM__

# %% [markdown]
# - A homogeneous solid transparent and refracting medium bounded by two plane refracting surfaces inclined at an angle called a prism

# %% [markdown]
# 1. PQ and PR are refracting surfaces
#
# 2. ∠QPR = A is called refracting angle or the angle of prism or apex angle
#
# 3. δ = angle of deviation

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __18.9 REFRACTION AT SPHERICAL SURFACES__
