# %% [markdown]
# # ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-16 OBJECTIVE II QUESTIONS____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# __Q1__

# %% [markdown]
# (d)

# %% [markdown]
# __Q2__

# %% [markdown]
# (a), (c)

# %% [markdown]
# __Q3__

# %% [markdown]
# (b), (c), (d)

# %% [markdown]
# __Q4__

# %% [markdown]
# (c)

# %% [markdown]
# __Q5__

# %% [markdown]
# (a), (d)
