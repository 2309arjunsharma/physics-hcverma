# %% [markdown]
# # ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-15 WAVE MOTION AND WAVES ON A STRING________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __15.1 WAVE MOTION__

# %% [markdown]
# - _Wave motion_ is the transfer of energy through a medium without permanent displacement of particles. Particles oscillate around fixed positions, creating disturbances that travel as mechanical or electromagnetic waves. Examples include sound, water waves, and light, all showing rhythmic propagation of energy.

# %% [markdown]
# - The transfer of energy and momentum without the actual displacement of the medium particle is called wave

# %% [markdown]
# - Types of waves
#
#     1. Based on requirement of medium
#
#     2. Based on motion of the medium particles
#
#     3. Based on energy propagation
#
#     4. Based on direction of propagation

# %% [markdown]
# - The waves requiring a medium are called _mechanical waves_ and those which do not require a medium are called _nonmechanical waves_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## __15.2 WAVE PULSE ON A STRING__

# %% [markdown]
# - When a disturbance is localised only to a small part of the space at a time, we say that a _wave pulse_ is passing through that part of the space
#
# - If the source is active for some extended time repeating its motion several times, we get a _wave train_ or a _wave packet_

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________
