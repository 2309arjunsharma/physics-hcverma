# %% [markdown]
# # __SHORT ANSWER SOLUTIONS__

# %% [markdown]
# ## __CH9__

# %% [markdown]
# __Q1__

# %% [markdown]
# - Yes, COM of a body can be at a point outside the body

# %% [markdown]
# __Q2__
