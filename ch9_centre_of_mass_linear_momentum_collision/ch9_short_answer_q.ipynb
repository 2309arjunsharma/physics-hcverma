# %% [markdown]
# # __SHORT ANSWER SOLUTIONS__

# %% [markdown]
# ## __CH9__

# %% [markdown]
# __Q1__

# %% [markdown]
# - Yes, COM of a body can be at a point outside the body

# %% [markdown]
# __Q2__

# %% [markdown]
# - If all the particles lie in the x-y plane, then it is necessary that Centre of Mass also lies in x-y plane

# %% [markdown]
# __Q3__

# %% [markdown]
# - If all the particles of a system lie in a cube then it is necessary that the COM be in a cube
# - For 2 particle system COM always lies in between them on the line joining the particles following the same logic we can say that COM lie inside the cube

# %% [markdown]
# __Q4__

# %% [markdown]
# - (a) Yes, it can be
#
# - (b) Yes, it is necessary
#
# - (c) No, it is not necessary, as COC of two charge system can be outside the line segment joining the charges

# %% [markdown]
# __Q5__

# %% [markdown]
# - No, the earth does attract other particles

# %% [markdown]
# __Q6__

# %% [markdown]
# - So, here the component of tension is the force due to which the linear momentum of the bob is increasing

# %% [markdown]
# __Q7__

# %% [markdown]
# - If f1 < F, then trunk will recoil
# - Since f1 > F, then trunk will not recoil

# %% [markdown]
# __Q8__

# %% [markdown]
# - It is necessary that the particles acquire a common velocity atleast for one instant

# %% [markdown]
# __Q9__

# %% [markdown]
# - A and B are in non-inertial frame
# - There is no change in the result because elevator is accelerating in vertical direction
# - So psuedo force will act in vertical direction which has no effect on horizontal motion

# %% [markdown]
# __Q10__
# - Yes the result will if the car is accelerated on a horizontal road
# - #" Collision = No external force
# - Momentum conservation not valid
# - Velocity of separation = velocity of approach not valid

# %% [markdown]
# __Q11__

# %% [markdown]
# - P(net) = 2(-2) + 4(2) = -4 + 8
# - P(net) = 4 kg-m/s
# - It is not necessary that linear momentum is zero

# %% [markdown]
# __Q12__

# %% [markdown]
# - Linear momentum (p) = mv
# - p = mv
# - p² = m²v²

# %% [markdown]
# - KE = p²/2m
# - KE = Scalar quantity
# - p² = 2m(KE)
# - p = √(2m(KE)) magnitude
# - Therefore, we cannot find direction

# %% [markdown]
# __Q13__

# %% [markdown]
# - Less than r/2
