# %% [markdown]
# # __OBJECTIVE I__

# %% [markdown]
# __Q1__

# %% [markdown]
# - (c) A is correct but B is wrong

# %% [markdown]
# __Q2__

# %% [markdown]
# - (d) B implies A but A does not imply B

# %% [markdown]
# __Q3__

# %% [markdown]
# - (d) B implies A but A does not imply B

# %% [markdown]
# __Q4__

# %% [markdown]
# - (d) both A and B are false

# %% [markdown]
# __Q5__

# %% [markdown]
# - (b) <= R

# %% [markdown]
# __Q6__

# %% [markdown]
# - (b) inside the square plate

# %% [markdown]
# __Q7__

# %% [markdown]
# - (b) 1/2 a

# %% [markdown]
# __Q8__

# %% [markdown]
# - (b) The kinetic energy but not the linear momentum

# %% [markdown]
# __Q9__

# %% [markdown]
# - (c) Gravitational potential energy of the block

# %% [markdown]
# __Q10__

# %% [markdown]
# - (d) is independent of h

# %% [markdown]
# __Q11__

# %% [markdown]
# - (c) does not shift horizontally

# %% [markdown]
# __Q12__

# %% [markdown]
# - (b) of the box plus the ball system remains constant

# %% [markdown]
# __Q13__

# %% [markdown]
# - (c) in opposite directions with speeds

# %% [markdown]
# __Q14__

# %% [markdown]
# - (c) 2mv2/r must be acting on the system

# %% [markdown]
# __Q15__

# %% [markdown]
# - (d) momentum, but neither kinetic energy nor temperature

# %% [markdown]
# __Q16__

# %% [markdown]
# - (d) m1, v1 + m2v2 must be parallel to v

# %% [markdown]
# __Q17__

# %% [markdown]
# - (a) 3v cos0

# %% [markdown]
# __Q18__

# %% [markdown]
# - (a) the initial kinetic energy is equal to the final kinetic energy

# %% [markdown]
# __Q19__

# %% [markdown]
# - (b)
