# %% [markdown]
# # __OBJECTIVE I__

# %% [markdown]
# __Q1__

# %% [markdown]
# - (c) A is correct but B is wrong

# %% [markdown]
# __Q2__

# %% [markdown]
# __Q3__

# %% [markdown]
# __Q4__

# %% [markdown]
# __Q5__

# %% [markdown]
# __Q6__

# %% [markdown]
# __Q7__

# %% [markdown]
# __Q8__

# %% [markdown]
# __Q9__

# %% [markdown]
# __Q10__

# %% [markdown]
# __Q11__

# %% [markdown]
# __Q12__

# %% [markdown]
# __Q13__

# %% [markdown]
# __Q14__

# %% [markdown]
# __Q15__

# %% [markdown]
# __Q16__

# %% [markdown]
# __Q17__

# %% [markdown]
# __Q18__

# %% [markdown]
# __Q19__
