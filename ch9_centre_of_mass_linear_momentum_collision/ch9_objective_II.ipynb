# %% [markdown]
# # __OBJECTIVE II__

# %% [markdown]
# __Q1__

# %% [markdown]
# - none of the options

# %% [markdown]
# __Q2__

# %% [markdown]
# - (c), (d)

# %% [markdown]
# __Q3__

# %% [markdown]
# - (a), (b)

# %% [markdown]
# __Q4__

# %% [markdown]
# - (b), (c)

# %% [markdown]
# __Q5__

# %% [markdown]
# - (b), (d)

# %% [markdown]
# __Q6__

# %% [markdown]
# - (d)

# %% [markdown]
# __Q7__

# %% [markdown]
# - (a), (d)

# %% [markdown]
# __Q8__

# %% [markdown]
# - (b), (c), (d)

# %% [markdown]
# __Q9__

# %% [markdown]
# - (c), (d)

# %% [markdown]
# __Q10__

# %% [markdown]
# - (b), (c)

# %% [markdown]
# __Q11__

# %% [markdown]
# - (a), (b), (c), (d)
