# %% [markdown]
# # __OBJECTIVE II__

# %% [markdown]
# __Q1__

# %% [markdown]
# - none of the options

# %% [markdown]
# __Q2__

# %% [markdown]
# - (c), (d)

# %% [markdown]
# __Q3__

# %% [markdown]
# __Q4__

# %% [markdown]
# __Q5__
