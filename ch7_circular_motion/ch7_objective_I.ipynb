# %% [markdown]
# # __OBJECTIVE I__

# %% [markdown]
# __Q1__
# - (d) Its velocity and acceleration both change

# %% [markdown]
# __Q2__
# - (d) 1

# %% [markdown]
# __Q3__
# - (b) Na > Nb

# %% [markdown]
# __Q4__
# - (d) zero

# %% [markdown]
# __Q5__
# - (b) m w20a

# %% [markdown]
# __Q6__
# - (a) 10cm/s, 10cm/s2

# %% [markdown]
# __Q7__
# - (c) mg is not greater than mv2/r
