# %% [markdown]
# # __CH-17 OBJECTIVE I__

# %% [markdown]
# __Q1__

# %% [markdown]
# c)

# %% [markdown]
# __Q2__

# %% [markdown]
# d)

# %% [markdown]
# __Q3__

# %% [markdown]
# d)

# %% [markdown]
# __Q4__

# %% [markdown]
# d)

# %% [markdown]
# c)

# %% [markdown]
# b)

# %% [markdown]
# a)

# %% [markdown]
# d)

# %% [markdown]
# d)

# %% [markdown]
# a)

# %% [markdown]
# a)

# %% [markdown]
# d)

# %% [markdown]
# d)

# %% [markdown]
# c)

# %% [markdown]
# b)

# %% [markdown]
# c)

# %% [markdown]
# a)
