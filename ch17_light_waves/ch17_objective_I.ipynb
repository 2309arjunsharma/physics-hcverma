# %% [markdown]
# # __CH-17 OBJECTIVE I__

# %% [markdown]
# __Q1__

# %% [markdown]
# c) both particle and wave phenomenon

# %% [markdown]
# __Q2__

# %% [markdown]
# d) neither on elasticity nor on inertia

# %% [markdown]
# __Q3__

# %% [markdown]
# d) electric field

# %% [markdown]
# __Q4__

# %% [markdown]
# d) Polarization

# %% [markdown]
# __Q5__

# %% [markdown]
# c) its wavelength decreases but frequency remains unchanged

# %% [markdown]
# __Q6__

# %% [markdown]
# b) Frequency

# %% [markdown]
# __Q7__

# %% [markdown]
# a) λ(a) > λ(f)

# %% [markdown]
# __Q8__

# %% [markdown]
# d) A laser

# %% [markdown]
# __Q9__

# %% [markdown]
# d) cos-¹(1/√3)

# %% [markdown]
# __Q10__

# %% [markdown]
# a) plane

# %% [markdown]
# __Q11__

# %% [markdown]
# a) point source

# %% [markdown]
# __Q12__

# %% [markdown]
# d) having a constant phase difference

# %% [markdown]
# __Q13__

# %% [markdown]
# d) interference of light

# %% [markdown]
# __Q14__

# %% [markdown]
# c) 9:4

# %% [markdown]
# __Q15__

# %% [markdown]
# b) I₀/4

# %% [markdown]
# __Q16__

# %% [markdown]
# c) remain same

# %% [markdown]
# __Q17__

# %% [markdown]
# a) the fridge width will decrease
