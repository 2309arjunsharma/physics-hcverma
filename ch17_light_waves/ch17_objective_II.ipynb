# %% [markdown]
# # __CH-17 OBJECTIVE II__

# %% [markdown]
# __Q1__

# %% [markdown]
# a), c)

# %% [markdown]
# __Q2__

# %% [markdown]
# b), c)

# %% [markdown]
# __Q3__

# %% [markdown]
# b), c), d)

# %% [markdown]
# __Q4__

# %% [markdown]
# c), d)

# %% [markdown]
# __Q5__

# %% [markdown]
# c), d)

# %% [markdown]
# __Q6__

# %% [markdown]
# a), d)

# %% [markdown]
# __Q7__

# %% [markdown]
# a)

# %% [markdown]
# __Q8__

# %% [markdown]
# b)

# %% [markdown]
# __Q9__

# %% [markdown]
# a), b), d)

# %% [markdown]
# __Q10__

# %% [markdown]
# a), d)
