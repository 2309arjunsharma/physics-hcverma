# %% [markdown]
# # __CH-17 SHORT ANS QUESTION__

# %% [markdown]
# __Q1__

# %% [markdown]
# - No,
#
# - Yes
#
# - Infinite

# %% [markdown]
# __Q2__

# %% [markdown]
# - Yes

# %% [markdown]
# __Q3__

# %% [markdown]
# - More

# %% [markdown]
# __Q4__

# %% [markdown]
# - Yes

# %% [markdown]
# __Q5__

# %% [markdown]
# - Yes

# %% [markdown]
# __Q6__

# %% [markdown]
# - Yes

# %% [markdown]
# __Q7__

# %% [markdown]
# - No
#
# - Yes
