# %% [markdown]
# # ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-13 OBJECTIVE I QUESTIONS____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# __Q1__

# %% [markdown]
# b) the forces between the molecules is stronger in solid than in liquids

# %% [markdown]
# __Q2__

# %% [markdown]
# b) The first is valid but not the second

# %% [markdown]
# __Q3__

# %% [markdown]
# c) Maximum in vessel C

# %% [markdown]
# __Q4__

# %% [markdown]
# d) Equal in all the vessels

# %% [markdown]
# __Q5__

# %% [markdown]
# __Q6__

# %% [markdown]
# __Q7__

# %% [markdown]
# __Q8__

# %% [markdown]
# __Q9__

# %% [markdown]
# __Q10__

# %% [markdown]
# __Q11__

# %% [markdown]
# __Q12__

# %% [markdown]
# __Q13__

# %% [markdown]
# __Q14__

# %% [markdown]
# __Q15__

# %% [markdown]
# __Q16__

# %% [markdown]
# __Q17__

# %% [markdown]
# __Q18__

# %% [markdown]
# __Q19__

# %% [markdown]
# __Q20__

# %% [markdown]
# __Q21__

# %% [markdown]
# __Q22__
