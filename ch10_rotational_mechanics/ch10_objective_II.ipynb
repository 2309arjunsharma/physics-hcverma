# %% [markdown]
# # __OBJECTIVE II__

# %% [markdown]
# __Q1__

# %% [markdown]
# (b), (d)

# %% [markdown]
# __Q2__

# %% [markdown]
# __Q3__

# %% [markdown]
# __Q4__

# %% [markdown]
# __Q5__

# %% [markdown]
# __Q6__

# %% [markdown]
# __Q7__
