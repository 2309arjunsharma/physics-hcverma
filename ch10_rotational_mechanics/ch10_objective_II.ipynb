# %% [markdown]
# # __OBJECTIVE II__

# %% [markdown]
# __Q1__

# %% [markdown]
# (b), (d)

# %% [markdown]
# __Q2__

# %% [markdown]
# (b)

# %% [markdown]
# __Q3__

# %% [markdown]
# (b), (c), (d)

# %% [markdown]
# __Q4__

# %% [markdown]
# (a), (b)

# %% [markdown]
# __Q5__

# %% [markdown]
# (c)

# %% [markdown]
# __Q6__

# %% [markdown]
# (b)

# %% [markdown]
# __Q7__

# %% [markdown]
# (d)

# %% [markdown]
# __Q8__

# %% [markdown]
# (a), (c), (d)

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__
