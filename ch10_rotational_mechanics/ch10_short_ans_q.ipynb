# %% [markdown]
# # __SHORT ANSWERS__

# %% [markdown]
# __Q1__

# %% [markdown]
# No it cannot

# %% [markdown]
# __Q2__

# %% [markdown]
# Pendulum = Rotational Motion

# %% [markdown]
# Axis of rotation passes through commom centre of these particles

# %% [markdown]
# __Q3__

# %% [markdown]
# No, Only same dimensional quantities can be added or subtracted

# %% [markdown]
# __Q4__

# %% [markdown]
# Yes, there is an angular rotation of the ball about its centre [Q]

# %% [markdown]
# About 'P', in any time t

# %% [markdown]
# __Q5__

# %% [markdown]
# No, we cannot see the other face of the moon from the earth

# %% [markdown]
# Yes, we can see all the faces of the earth from moon

# %% [markdown]
# __Q6__

# %% [markdown]
# Yes, it is always correct

# %% [markdown]
# Because the weight of the body is parallel to the Axis of Rotation and any force parallel to the Axis of Rotation cannot provide rotational motion

# %% [markdown]
# __Q7__

# %% [markdown]
# No

# %% [markdown]
# __Q8__

# %% [markdown]
# No

# %% [markdown]
# __Q9__

# %% [markdown]
# Hence proved

# %% [markdown]
# __Q10__

# %% [markdown]
# F(net) = 0

# %% [markdown]
# So the body is in translational equilibrium but is not in rotational equilibrium

# %% [markdown]
# __Q11__

# %% [markdown]
# About point P the 'L' of the body is zero

# %% [markdown]
# __Q12__

# %% [markdown]
# Because the angle between r' and F(net) is not zero

# %% [markdown]
# No, it is not necessary

# %% [markdown]
# __Q13__

# %% [markdown]
# Yes, it will also be zero about any other point

# %% [markdown]
# __Q14__

# %% [markdown]
# This mg force produces a rotational effect

# %% [markdown]
# __Q15__

# %% [markdown]
# While touching his toes, person applies a force along his hand

# %% [markdown]
# This force provides torque to the body along COM

# %% [markdown]
# Thus, the fat person falls

# %% [markdown]
# __Q16__

# %% [markdown]
# At the top, ladder is more likely to slip

# %% [markdown]
# __Q17__

# %% [markdown]
# F(net) = 0

# %% [markdown]
# No, the torque of the two weights about the middle is not zero

# %% [markdown]
# __Q18__

# %% [markdown]
# So it is easy to set the rod in rotation when clamped at B

# %% [markdown]
# __Q19__

# %% [markdown]
# Yes

# %% [markdown]
# __Q20__

# %% [markdown]
# Ice caps near the poles keeps mass of water near axis of rotation

# %% [markdown]
# As the ice near the poles melts and flows towards the equator, so, mass moves away from Axis of rotation

# %% [markdown]
# r increases

# %% [markdown]
# __Q21__

# %% [markdown]
# Time order

# %% [markdown]
# Solid sphere < Disc < Hollow Sphere < Ring
