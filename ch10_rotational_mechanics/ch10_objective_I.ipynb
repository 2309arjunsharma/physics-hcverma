# %% [markdown]
# # __OBJECTIVE I__

# %% [markdown]
# __Q1__

# %% [markdown]
# (c) 0

# %% [markdown]
# __Q2__

# %% [markdown]
# (c) 0

# %% [markdown]
# __Q3__

# %% [markdown]
# (b) remains constant

# %% [markdown]
# __Q4__

# %% [markdown]
# (d) ω is independent of r

# %% [markdown]
# __Q5__

# %% [markdown]
# (c) y = 2x

# %% [markdown]
# __Q6__

# %% [markdown]
# (c) horizontal and intersecting axis

# %% [markdown]
# __Q7__

# %% [markdown]
# (b) horizontal and skew with the axis

# %% [markdown]
# __Q8__

# %% [markdown]
# (a) r.R = 0 and F.R = 0

# %% [markdown]
# __Q__

# %% [markdown]
# (d)

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__

# %% [markdown]
# __Q__
