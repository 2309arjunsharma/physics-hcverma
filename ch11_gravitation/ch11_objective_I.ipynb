# %% [markdown]
# # ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-11 OBJECTIVE I QUESTIONS____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# __Q1__

# %% [markdown]
# (b) 6.4 m/s²

# %% [markdown]
# __Q2__

# %% [markdown]
# (c) 6.4 m/s²

# %% [markdown]
# __Q3__

# %% [markdown]
# (c) C

# %% [markdown]
# __Q4__

# %% [markdown]
# (d) 1/2³ W at the planet

# %% [markdown]
# __Q5__

# %% [markdown]
# (a) 1/2 mgR

# %% [markdown]
# __Q6__

# %% [markdown]
# (c) -5 J/kg

# %% [markdown]
# __Q7__

# %% [markdown]
# (c) B is correct but A is wrong

# %% [markdown]
# __Q8__

# %% [markdown]
# (d) Both A and B are wrong

# %% [markdown]
# __Q9__

# %% [markdown]
# __Q10__

# %% [markdown]
# __Q11__

# %% [markdown]
# __Q12__

# %% [markdown]
# __Q13__

# %% [markdown]
# __Q14__

# %% [markdown]
# __Q15__

# %% [markdown]
# __Q16__

# %% [markdown]
# __Q17__
