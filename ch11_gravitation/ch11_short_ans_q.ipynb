# %% [markdown]
# # __________________________________CH-11 SHORT ANS QUESTIONS__________________________________

# %% [markdown]
# __Q1__

# %% [markdown]
# No, these two particles cannot be in equilibrium
#
# Since in equilibrium, F(net) on any particle should be zero
#
# In circular motion the particles can be in equilibrium
#
# Yes, in case of three particles, they can be in equilibrium
#
# In case of single particle, it may or may not be in equilibrium

# %% [markdown]
# __Q2__

# %% [markdown]
# Weight = mg
#
# No, there is no meaning of weight of the earth

# %% [markdown]
# __Q3__

# %% [markdown]
# They both fall together because they fall with an acceleration (g) which is independent of mass

# %% [markdown]
# __Q4__

# %% [markdown]
# If the objects are massless, then they will not exert gravitational force on each other

# %% [markdown]
# __Q5__

# %% [markdown]
# Since moon is very far from Sun and close to the earth
#
# The gravitation influence of earth is more powerful than Sun's gravitation

# %% [markdown]
# __Q6__

# %% [markdown]
# No, weight remains the same
#
# So we can neglect the F(s)

# %% [markdown]
# Weight = mg

# %% [markdown]
# __Q7__

# %% [markdown]
# The force responsible for this acceleration 'g' is the force of gravitation between the apple and Earth
#
# Here apple is falling towards the Earth with acceleration 'g'
#
# Since insect is in accelerating frame that is why it seems that Earth is falling towards it

# %% [markdown]
# __Q8__

# %% [markdown]
# Gravitational field = 2K/r³
#
# Field is proportional to 1/r²
#
# No, such system does not exist
#
# With negative masses, a dipole will form, then such system is possible

# %% [markdown]
# __Q9__

# %% [markdown]
# As u = 0
#
# By using formula,
#
# u = -GMm/r, we cannot choose PE for r = ∞ to be 20 J
#
# In order to have PE = 20J at r = ∞, the formula should be
#
# u = -GMm/r + 20

# %% [markdown]
# __Q10__

# %% [markdown]
# The balance used to measure the mass is calibrated according to the place to give its correct reading
#
# Therefore, a beam balance can be used

# %% [markdown]
# __Q11__

# %% [markdown]
# Actual Weight = mg
#
# Apparent Weightt = Net force
#
# It is the app. weight when rotation of earth is considered
#
# So an extra mw²r is added due to Rotation of Earth

# %% [markdown]
# __Q12__

# %% [markdown]
# g = GM/r²
#
# Here, % change is less than 10%
#
# Yes, there will be a change and of 2%

# %% [markdown]
# __Q13__

# %% [markdown]
# No, the nut will not land on Earth. It will start revolving in the orbit of satellite with the same orbital speed due to inertia of motion.
#
# In order to make it land on earth, an astronaut has to project it towards the earth with some speed

# %% [markdown]
# __Q14__

# %% [markdown]
# Yes, it is necessary

# %% [markdown]
# __Q15__

# %% [markdown]
# Yes, Geostationary Satellites are those which are at a height of 36000 km
#
# They have same speed as that of the earth and due to this they take same time i.e. 24 hours to complete 1 revolution

# %% [markdown]
# __Q16__

# %% [markdown]
# Delhi is at 28° from the equator, no geostationary satellite can be situated avove New Delhi as it lies only above equator

# %% [markdown]
# __Q17__

# %% [markdown]
# Since V = 8 km/s, so a person on the Earth does not feel the weightlessness as felt by a person in a satellite
