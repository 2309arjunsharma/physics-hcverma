# %% [markdown]
# # __OBJECTIVE I__

# %% [markdown]
# __Q1__

# %% [markdown]
# - (d) the speed does not depend on the initial direction

# %% [markdown]
# __Q2__

# %% [markdown]
# - (b) 2E

# %% [markdown]
# __Q3__

# %% [markdown]
# - (d) -1/4kx²

# %% [markdown]
# __Q4__

# %% [markdown]
# - (c) potential energy

# %% [markdown]
# __Q5__

# %% [markdown]
# - (a) total energy

# %% [markdown]
# __Q6__

# %% [markdown]
# - (b) Kinetic Energy

# %% [markdown]
# __Q7__

# %% [markdown]
# - (c) Potential energy

# %% [markdown]
# __Q8__

# %% [markdown]
# - (c) mgvt sin²θ

# %% [markdown]
# __Q9__

# %% [markdown]
# - (d) none of these

# %% [markdown]
# __Q10__

# %% [markdown]
# - (c) √3gl
