# %% [markdown]
# # __SHORT ANSWER QUESTION__

# %% [markdown]
# __Q1__
# - PE is stored energy!!
# - F = weight = mg
# - S = h
# - W(you) = F.S
# - W(you) = mgh
# - W(you) = W(cons)
# - No, it is not

# %% [markdown]
# __Q2__
