# %% [markdown]
# # __SHORT ANSWER QUESTION__

# %% [markdown]
# __Q1__
# - PE is stored energy!!
# - F = weight = mg
# - S = h
# - W(you) = F.S
# - W(you) = mgh
# - W(you) = W(cons)
# - No, it is not

# %% [markdown]
# __Q2__

# %% [markdown]
# - It does not depend on angle of inclination

# %% [markdown]
# __Q3__

# %% [markdown]
# - m(A)a > f(K)
# - after sometime box A will fall in backward direction
# - here, f(K) and direction of motion both are in same direction.
# - W(f(K)) = +ve
#
# - w(f(K)) = 0
# - there is motion of ground

# %% [markdown]
# __Q4__

# %% [markdown]
# - If both blocks A and B are moving together
# - here W(f(s)) ≠ 0
# - but W(f(s)) = +ve

# %% [markdown]
# __Q5__

# %% [markdown]
# - here Normal force applied by the lift is responsible for upward motion of box
# - Yes, W(N) ≠ 0
# - W(N) = +ve

# %% [markdown]
# __Q6__

# %% [markdown]
# - Initial KE of system = KE1 + KE2
# - Initially both blocks are at rest
# - KE1 = 0
# - after releasing KE increases as both boxes move towards each other with increasing speed

# %% [markdown]
# __Q7__

# %% [markdown]
# - Wall = KE
# - W(ext.) + W(N) + W(mg) +W(pseudo) = KE
# - Yes, we can apply WET in non-inertial frame
# - But make sure to consider pseudo force.

# %% [markdown]
# __Q8__
# - No, it does not depend on the speed.
# - W(mg) = -mg(ssinθ)

# %% [markdown]
# __Q9__
# - PE depends on reference
# - Both persons have different references
# - For both the persons PE is different
# - No, both are correct

# %% [markdown]
# __Q10__
# - Δu = fix value

# %% [markdown]
# __Q11__
# - While compressing
# - F and S both are in same direction
# - W = fscos0*
# -   = +ve
#
# - While expanding
# - F and S are in opposite directions
# - W = Fscos180*
# -   = -F.S = -ve

# %% [markdown]
# __Q12__

# %% [markdown]
# (a) +ve

# %% [markdown]
# (b) -ve

# %% [markdown]
# (c) zero

# %% [markdown]
# (d) -ve

# %% [markdown]
# (e)
# - In case of B, there will be relative motion so there will be some displacement
# - F(ext) = 0
# - Total external work on the two teams is zero

# %% [markdown]
# __Q13__
# - As apple falls down, height decreases due to which the potential energy also decreases
# - After it strikes the ground its PE remains the same (zero)

# %% [markdown]
# __Q14__
# - FOOD (CHEMICAL ENERGY) - W/D - PE
