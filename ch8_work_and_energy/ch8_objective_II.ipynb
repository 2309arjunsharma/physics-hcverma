# %% [markdown]
# # __OBJECTIVE II__

# %% [markdown]
# __Q1__ = (a) , (b)

# %% [markdown]
# __Q2__ = (a)

# %% [markdown]
# __Q3__ = (c) , (d)

# %% [markdown]
# __Q4__ = (d)

# %% [markdown]
# __Q5__ = (a) , (b), (d)

# %% [markdown]
# __Q6__ = (a) , (d)

# %% [markdown]
# __Q7__ = (a) , (d)

# %% [markdown]
# __Q8__ = (b) , (d)

# %% [markdown]
# __Q9__ = (a) , (b)

# %% [markdown]
# __Q10__ = (b)
