# %% [markdown]
# # ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-12 SHORT ANSWER QUESTIONS________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# __Q1__

# %% [markdown]
# 🢂 No, it is not periodic motion, as in periodic motion, particle repeats its path after fixed time period
#
# Here, in the question, we are not aware whether the person is following his routine or not

# %% [markdown]
# __Q2__

# %% [markdown]
# 🢂 For SHM
#
# F = Kx
#
# F = -K(-A)
#
# F = KA
#
# If F(extreme) = 0, then particle will not return
#
# No, the resultant force will not be zero at extreme

# %% [markdown]
# __Q3__

# %% [markdown]
# 🢂 In Non-Inertial frame, particle can exert SHM

# %% [markdown]
# __Q4__

# %% [markdown]
# 🢂 At extremes, it will be maximum
#
# At the means, it will be minimum

# %% [markdown]
# __Q5__

# %% [markdown]
# 🢂 As the creature follows UCM, therefore,
#
# Yes, its shadow moves in a SHM

# %% [markdown]
# __Q6__

# %% [markdown]
# 🢂 No. of ocillations are independent of the speed of the particle performing SHM

# %% [markdown]
# Therefore the particle crosses P and Q equal no. of times in a given time interval

# %% [markdown]
# __Q7__

# %% [markdown]
# 🢂 Due to damping extreme position changes
#
# But mean position remains fixed measuring time from mean position accuracy

# %% [markdown]
# __Q8__

# %% [markdown]
# 🢂 F(net) = F(ext) - μmg
#
# particle is moving in SHM.
#
# F(net) = -Kx
#
# F(ext) = -Kx + μmg
#
# γ = -mx + c
#
# i) x = -A
#
#     ⇛ F(ext) = (+KA + μmg)
#
# ii) x = A
#
#     ⇛ F(ext) = (-KA + μmg)
#
#     ⇛ assume KA > μmg
#
# When particle is moving in (-)ve direction
#
# f = μmg
#
# F(net) = F(ext) + f
#
# F(net) = F(ext) + μmg
#
# Since particle is moving in SHM
#
# F(net) = -Kx
#
# -Kx = F(ext) + μmg
#
# F(ext) = -Kx - μmg
#
# i) x = -A
#
#     ⇛ F(ext) = (KA - μmg)
#
#     ⇛ assume KA > μmg
#
# ii) x = A
#
#     ⇛ F(ext) = (-KA - μmg)
#
# iii) x = 0
#
#     ⇛ F(ext) = -μmg

# %% [markdown]
# __Q9__

# %% [markdown]
# __🢂__ No, μ cannot be negative
