# %% [markdown]
# # ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-12 OBJECTIVE I QUESTIONS____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# __Q1__

# %% [markdown]
# a) As x increases k increases

# %% [markdown]
# __Q2__

# %% [markdown]
# b) an extreme position

# %% [markdown]
# __Q3__

# %% [markdown]
# a) v(max)

# %% [markdown]
# __Q4__

# %% [markdown]
# d) Zero

# %% [markdown]
# __Q5__

# %% [markdown]
# c) 4A

# %% [markdown]
# __Q6__

# %% [markdown]
# d) Zero

# %% [markdown]
# __Q7__

# %% [markdown]
# d) Simple Harmonic with amplitude √A² + B²

# %% [markdown]
# __Q8__

# %% [markdown]
# c) on a circle

# %% [markdown]
# __Q9__

# %% [markdown]
# b) B

# %% [markdown]
# __Q10__

# %% [markdown]
# c) Phase

# %% [markdown]
# __Q11__

# %% [markdown]
# d) Remain E

# %% [markdown]
# __Q12__

# %% [markdown]
# a) 1/2 mw²A²

# %% [markdown]
# __Q13__

# %% [markdown]
# c) 2v

# %% [markdown]
# __Q14__

# %% [markdown]
# d) Become T/√2

# %% [markdown]
# __Q15__

# %% [markdown]
# d) √(k₂/k₁)

# %% [markdown]
# __Q16__

# %% [markdown]
# c) Remain same

# %% [markdown]
# __Q17__

# %% [markdown]
# c) Remain same

# %% [markdown]
# __Q18__

# %% [markdown]
# d) √6 times slower

# %% [markdown]
# __Q19__

# %% [markdown]
# d) give correct time

# %% [markdown]
# __Q20__

# %% [markdown]
# __Q21__
