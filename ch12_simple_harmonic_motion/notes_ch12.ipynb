# %% [markdown]
# # ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-12 SIMPLE HARMONIC MOTION________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### __12.1 SIMPLE HARMONIC MOTION__

# %% [markdown]
# - Harmonic motion is also known as periodic motion
#
# - When a body repeat its motion continuously on a definite path in a definite interval of time, then its motion is called periodic motion
#
# - The constant interval of time after which the motion is repeated is called the time period of motion (T).
#
# - Eg:
#
#     - Time period of a minute hand is 60 minutes.
#
#     - Earth takes 365 days to revolve on a definite path around the Sun
#
#     - Earth takes 24 hours to rotate on its axis
#
# - If a body moves to and fro on the same path, it is said to perform oscillations
#
# - Simple Harmonic Motion (SHM) is a special type of oscillation in which the particle oscillates on a straight line, the acceleration of the particle is always directed towards a fixed point on the line and its magnitude is proportional to the displacement of the particle from this point. This fixed point is called _centre of oscillation_

# %% [markdown]
# __α = - ω²x__
#
# - where ω² is a positive constant. If x is positive, α is negative and if x is negative, α is positive. This means that the acceleration is always directed towards the centre of oscillation

# %% [markdown]
# - Every oscillatary motion is periodic but every periodic motion is not oscillatory
#
# - If a body in periodic motion moves along the same path to and fro about a definite point (equilibrium position), then the motion of the body is a vibratory motion or oscillatory motion

# %% [markdown]
# - In oscillatory motion, a force acts on a body to bring it to mean position.
#
# - F = -k(x to the power n)
#     - where n = 1,3,5,7,9 .......
#
# - Eg: F = -kx³
#     - x = +ve , F = -ve
#     - x = -ve , F = +ve

# %% [markdown]
# ### __12.2 QUALITATIVE NATURE OF SIMPLE HARMONIC MOTION__

# %% [markdown]
# - SHM is the simplest form of vibratory or oscillatory motion
#
# - Every SHM is oscillatory but every oscillatory motion is not SHM
#
# - If n = 1 then it is SHM,
#
#     - F = -kx¹
#
# - Projection of the particle performing Uniform Circular Motion is performing SHM

# %% [markdown]
# - Types of SHM
#
#     - Linear SHM = Spring- pendulum system
#
#     - Angular SHM

# %% [markdown]
# ### __12.3 EQUATION OF MOTION OF A SIMPLE HARMONIC MOTION__

# %% [markdown]
# - In SHM of particle, the equation describing the position of particle as a function of time is called equation of SHM.
#
# - Equation of SHM is given by -
#
#     - 1. x = A sin(ωt)
#
#     - 2. x = A sin(ωt + φ)
#
#     - 3. x = A cos(ωt)

# %% [markdown]
# ### __12.4 TERMS ASSOCIATED WITH SIMPLE HARMONIC MOTION__

# %% [markdown]
# __(a) Amplitude__

# %% [markdown]
# The maximum displacement on either side from the centre of oscillation is called amplitude

# %% [markdown]
# __(b) Time Period__

# %% [markdown]
# The time taken to complete one complete oscillation from point O to A to O to B to O is called time period (T)
#
#     T = 2π/ω = 2π.√(m/k)
#
# where k is the force constant and m is the mass of the particle

# %% [markdown]
# __(c) Frequency and Angular Frequency__

# %% [markdown]
# The reciprocal of time period is called frequency
#
# Frequency represents the number of oscillations per unit time. It is measured in cycles per second, called Hertz (Hz)
#
#     v = 1/2π.√(k/m)
#
# The constant ω is called the angular frequency

# %% [markdown]
# __(d) Phase__
#
# The quantity Φ = ωt + δ is called the phase
#
# It determines the status of the particle in simple harmonic motion

# %% [markdown]
# __(e) Phase constant__

# %% [markdown]
# The constant δ appearing in phase equation is called phase constant
#
# This constant depends on the choice of the instant i=0
#
# The value of phase constant, however, depends on the form chosen

# %% [markdown]
# ### __12.5 SIMPLE HARMONIC MOTION AS A PROJECTION OF CIRCULAR MOTION__

# %% [markdown]
# - Simple Harmonic Motion (SHM) can be visualized as the projection of uniform circular motion onto a straight line.
#
# - Imagine a particle moving around a circle at constant angular velocity. If you shine a light and observe its shadow on a diameter, the shadow oscillates back and forth in SHM.
#
# - The displacement of this projection varies sinusoidally with time, matching the equations of SHM.
#
# - The restoring force in SHM corresponds to the radial component of circular motion.
#
# - Thus, SHM is essentially the one-dimensional projection of circular motion, linking oscillations of springs, pendulums, and vibrations to rotational dynamics.
#
# - _Thus, the projection of a uniform circular motion on a diameter of the circle is a simple harmonic motion_

# %% [markdown]
# ### __12.6 ENERGY CONSERVATION IN SIMPLE HARMONIC MOTION__

# %% [markdown]
# v = ω √(A² - x²)
#
# KE = 1/2 mv² = 1/2 mω²(A² - x²)
#
# KE = 1/2 K(A² - x²)

# %% [markdown]
# 1. Total Mechanical Energy
# - For a particle of mass m attached to a spring (spring constant k) oscillating with amplitude A:
#
#         E=1/2 kA²
#
# - This is the total energy of the system, which remains constant at all times.
#
# 2. Distribution of Energy
# - Potential Energy (PE):
#
#         U=1/2 kx²
#
# where x is the displacement from mean position.
#
# - Kinetic Energy (KE):
#
#         K= 1/2mv² = 1/2 K(A² - x²)
#
# - At any instant:
#
#         E = K+U = 1/2 KA²
#
# 4. Key Insights
#
# - Energy oscillates between KE and PE but never lost in ideal SHM (no friction, no damping).
#
# - At the mean position, velocity is maximum → KE is maximum.
#
# - At the extreme position, displacement is maximum → PE is maximum.
#
# - The sum of KE and PE is always constant, showing conservation of mechanical energy.
#
# 🎯 Why This Matters
#
# - SHM is a perfect example of energy conservation in oscillatory systems.
#
# - It builds intuition for later topics like waves, resonance, and quantum oscillators.

# %% [markdown]
# ### __12.7 ANGULAR SIMPLE HARMONIC MOTION__

# %% [markdown]
# ### __12.8 SIMPLE PENDULUM__

# %% [markdown]
# ### __12.9 PHYSICAL PENDULUM__
