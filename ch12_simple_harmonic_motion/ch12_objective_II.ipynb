# %% [markdown]
# # ________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________CH-12 OBJECTIVE II QUESTIONS________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# __Q1__

# %% [markdown]
# a), b)

# %% [markdown]
# __Q2__

# %% [markdown]
# a)

# %% [markdown]
# __Q3__

# %% [markdown]
# a)

# %% [markdown]
# __Q4__

# %% [markdown]
# d)

# %% [markdown]
# __Q5__

# %% [markdown]
# a), b), d)

# %% [markdown]
# __Q6__

# %% [markdown]
# c), d)

# %% [markdown]
# __Q7__

# %% [markdown]
# a)

# %% [markdown]
# __Q8__

# %% [markdown]
# a), b), c), d)

# %% [markdown]
# __Q9__

# %% [markdown]
# c), d)

# %% [markdown]
# __Q10__

# %% [markdown]
# a)

# %% [markdown]
# __Q11__

# %% [markdown]
# a), c), d)

# %% [markdown]
# __Q12__

# %% [markdown]
# d)

# %% [markdown]
# __Q13__

# %% [markdown]
# d)

# %% [markdown]
# __Q14__

# %% [markdown]
# a), b)

# %% [markdown]
# __Q15__

# %% [markdown]
# a), b)

# %% [markdown]
# __Q16__

# %% [markdown]
# a), b)
